# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzaib2021/6220-Course/blob/main/6220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install PyCaret**
#
# PyCaret is an open-source, low-code machine learning library in Python designed to make the end-to-end machine learning process easier and faster for both beginners and experienced data scientists. It offers a variety of tools and functions for data preparation, model training, model selection, and deployment.
#
# pip3 install pycaret==2.3.6 is a command used to install a specific version of the PyCaret library in Python. If you encounter an error message, try running the code again.

# %%
# install slim version (default)
# !pip install --user pycaret
# Out:
# Requirement already satisfied: pycaret in /root/.local/lib/python3.11/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.11/dist-packages (from pycaret) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /root/.local/lib/python3.11/site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /root/.local/lib/python3.11/site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /root/.local/lib/python3.11/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (8.6.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in /root/.local/lib/python3.11/site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /root/.local/lib/python3.11/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.11/dist-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.11/dist-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /root/.local/lib/python3.11/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /root/.local/lib/python3.11/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /root/.local/lib/python3.11/site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pycaret) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in /root/.local/lib/python3.11/site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /root/.local/lib/python3.11/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /root/.local/lib/python3.11/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from pycaret) (3.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in /root/.local/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.12.0->pycaret) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /root/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.14.0->pycaret) (9.1.2)
# Requirement already satisfied: dash>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.16)
# Requirement already satisfied: tsdownsample>=0.1.3 in /root/.local/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret) (3.0.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret) (2025.1.31)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /root/.local/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /root/.local/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.6)
# Requirement already satisfied: dash-html-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /usr/local/lib/python3.11/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.13.1)
# Requirement already satisfied: retrying in /root/.local/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.3.1)

# %%
#Run the below code in your notebook to check the installed version
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %% [markdown]
# **Install Analysis Extras for Explainable AI**

# %%
# !pip install pycaret[analysis]
# Out:
# Requirement already satisfied: pycaret[analysis] in /root/.local/lib/python3.11/site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (7.7.1)
# Requirement already satisfied: tqdm>=4.62.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (2.1.4)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (2.0.4)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.60.0)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (5.9.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (8.6.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (5.10.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (2.1.0)
# Requirement already satisfied: xxhash in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in /root/.local/lib/python3.11/site-packages (from pycaret[analysis]) (2.0.4)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (3.1.1)
# Requirement already satisfied: shap~=0.44.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.44.1)
# Requirement already satisfied: interpret>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.6.10)
# Requirement already satisfied: umap-learn>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.5.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (6.0.2)
# Requirement already satisfied: ydata-profiling>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (4.16.1)
# Requirement already satisfied: explainerdashboard>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.4.8)
# Requirement already satisfied: fairlearn==0.7.0 in /usr/local/lib/python3.11/dist-packages (from pycaret[analysis]) (0.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sktime==0.26.0->pycaret[analysis]) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in /root/.local/lib/python3.11/site-packages (from sktime==0.26.0->pycaret[analysis]) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.4.0->pycaret[analysis]) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (8.1.8)
# Requirement already satisfied: dash-auth in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (2.3.0)
# Requirement already satisfied: dash-bootstrap-components>=1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (1.7.1)
# Requirement already satisfied: dash>=2.10.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (2.18.2)
# Requirement already satisfied: dtreeviz>=2.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (2.2.2)
# Requirement already satisfied: flask_simplelogin in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (0.2.0)
# Requirement already satisfied: Flask-WTF>=1.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (1.2.2)
# Requirement already satisfied: graphviz>=0.18.2 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (0.20.3)
# Requirement already satisfied: jupyter_dash>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (0.4.2)
# Requirement already satisfied: oyaml in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (1.0)
# Requirement already satisfied: waitress in /usr/local/lib/python3.11/dist-packages (from explainerdashboard>=0.3.8->pycaret[analysis]) (3.0.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret[analysis]) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn>=0.12.0->pycaret[analysis]) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.12.0->pycaret[analysis]) (3.21.0)
# Requirement already satisfied: interpret-core==0.6.10 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (0.6.10)
# Requirement already satisfied: ipykernel>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (6.17.1)
# Requirement already satisfied: SALib>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (1.5.1)
# Requirement already satisfied: dill>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (0.3.9)
# Requirement already satisfied: aplr>=10.6.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (10.8.0)
# Requirement already satisfied: dash-core-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (2.0.0)
# Requirement already satisfied: dash-html-components>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (2.0.0)
# Requirement already satisfied: dash-table>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (5.0.0)
# Requirement already satisfied: dash-cytoscape>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (1.0.2)
# Requirement already satisfied: gevent>=1.3.6 in /usr/local/lib/python3.11/dist-packages (from interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (24.11.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /root/.local/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret[analysis]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.5.0->pycaret[analysis]) (4.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[analysis]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[analysis]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.6.5->pycaret[analysis]) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<3.8.0->pycaret[analysis]) (2.8.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[analysis]) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[analysis]) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=4.2.0->pycaret[analysis]) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.0->pycaret[analysis]) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret[analysis]) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.2.0->pycaret[analysis]) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.14.0->pycaret[analysis]) (9.1.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from plotly-resampler>=0.8.3.1->pycaret[analysis]) (3.10.16)
# Requirement already satisfied: tsdownsample>=0.1.3 in /root/.local/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret[analysis]) (0.1.4.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret[analysis]) (3.0.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from pmdarima>=2.0.4->pycaret[analysis]) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[analysis]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[analysis]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->pycaret[analysis]) (2025.1.31)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.11/dist-packages (from shap~=0.44.0->pycaret[analysis]) (0.0.7)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.2->pycaret[analysis]) (0.5.13)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (2.11.2)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling>=4.3.1->pycaret[analysis]) (0.8.1)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (0.12.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (1.12)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling>=4.3.1->pycaret[analysis]) (1.9.2)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling>=4.3.1->pycaret[analysis]) (1.8.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /root/.local/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /root/.local/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (3.0.6)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (4.13.1)
# Requirement already satisfied: retrying in /root/.local/lib/python3.11/site-packages (from dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (1.6.0)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (from dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[analysis]) (0.1.5)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[analysis]) (8.3.5)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.11/dist-packages (from Flask-WTF>=1.1->explainerdashboard>=0.3.8->pycaret[analysis]) (2.2.0)
# Requirement already satisfied: wtforms in /usr/local/lib/python3.11/dist-packages (from Flask-WTF>=1.1->explainerdashboard>=0.3.8->pycaret[analysis]) (3.2.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (6.1.12)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.10.0->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.5.0->pycaret[analysis]) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[analysis]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[analysis]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[analysis]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret[analysis]) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret[analysis]) (4.3.7)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.11/dist-packages (from jupyter_dash>=0.4.1->explainerdashboard>=0.3.8->pycaret[analysis]) (1.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.5.0->pycaret[analysis]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret[analysis]) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling>=4.3.1->pycaret[analysis]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling>=4.3.1->pycaret[analysis]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling>=4.3.1->pycaret[analysis]) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret[analysis]) (1.17.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling>=4.3.1->pycaret[analysis]) (3.4.2)
# Requirement already satisfied: puremagic in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling>=4.3.1->pycaret[analysis]) (1.28)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (6.5.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=2.10.1->explainerdashboard>=0.3.8->pycaret[analysis]) (1.9.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (7.2)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gevent>=1.3.6->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (3.1.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from SALib>=1.3.3->interpret-core[aplr,dash,debug,linear,notebook,plotly,sensitivity,shap]==0.6.10->interpret>=0.2.7->pycaret[analysis]) (0.70.17)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[analysis]) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->dtreeviz>=2.1->explainerdashboard>=0.3.8->pycaret[analysis]) (1.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret[analysis]) (1.3.1)

# %% [markdown]
# ## **Principal Component Analysis**
#
# PCA stands for Principal Component Analysis, and it is a widely used technique in data analysis and machine learning for reducing the dimensionality of large datasets. The basic idea behind PCA is to transform a set of high-dimensional variables into a smaller set of uncorrelated variables called principal components, while retaining as much of the original variance as possible.

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  2.1.4
# Seaborn version:  0.13.2

# %% [markdown]
# **Dataset**
#
# The examined group comprised kernels belonging to three different varieties of wheat: Kama, Rosa and Canadian, 70 elements each, randomly selected for
# the experiment. High quality visualization of the internal kernel structure was detected using a soft X-ray technique. It is non-destructive and considerably cheaper than other more sophisticated imaging techniques like scanning microscopy or laser technology. The images were recorded on 13x18 cm X-ray KODAK plates. Studies were conducted using combine harvested wheat grain originating from experimental fields, explored at the Institute of Agrophysics of the Polish Academy of Sciences in Lublin.
#
# The data set can be used for the tasks of classification and cluster analysis.
#
#
# Attribute Information:
#
# To construct the data, seven geometric parameters of wheat kernels were measured:
# 1. area A,
# 2. perimeter P,
# 3. compactness C = 4*pi*A/P^2,
# 4. length of kernel,
# 5. width of kernel,
# 6. asymmetry coefficient
# 7. length of kernel groove.
# All of these parameters were real-valued continuous.
#
# https://archive.ics.uci.edu/ml/datasets/seeds

# %% [markdown]
# **Read the dataset**
#
# **pd.read_csv** is a function in the pandas library in Python that is used to read a CSV (Comma Separated Values) file and convert it into a pandas DataFrame.

# %%
import pandas as pd

# Read CSV file into DataFrame
df = pd.read_csv('/content/bodyfat.csv')

# Binarize BodyFat into 3 classes: 0 = Low, 1 = Normal, 2 = High
low_threshold = df['BodyFat'].quantile(0.33)
high_threshold = df['BodyFat'].quantile(0.66)

def classify_bodyfat(x):
    if x < low_threshold:
        return 0  # Low
    elif x < high_threshold:
        return 1  # Normal
    else:
        return 2  # High

df['BodyFat_class'] = df['BodyFat'].apply(classify_bodyfat)

# Select exactly 7 most important features + BodyFat_class
selected_features = [
    'Density', 'Abdomen', 'Weight', 'Chest',
    'Neck', 'Height', 'Age',
    'BodyFat_class'
]
df = df[selected_features]

# Show first 25 rows
df.head(25)
# Out:
#     Density  Abdomen  Weight  Chest  Neck  Height  Age  BodyFat_class
# 0    1.0708     85.2  154.25   93.1  36.2   67.75   23              0
# 1    1.0853     83.0  173.25   93.6  38.5   72.25   22              0
# 2    1.0414     87.9  154.00   95.8  34.0   66.25   22              2
# 3    1.0751     86.4  184.75  101.8  37.4   72.25   26              0
# 4    1.0340    100.0  184.25   97.3  34.4   71.25   24              2
# 5    1.0502     94.4  210.25  104.5  39.0   74.75   24              1
# 6    1.0549     90.7  181.00  105.1  36.4   69.75   26              1
# 7    1.0704     88.5  176.00   99.6  37.8   72.50   25              0
# 8    1.0900     82.5  191.00  100.9  38.1   74.00   25              0
# 9    1.0722     88.6  198.25   99.6  42.1   73.50   23              0
# 10   1.0830     83.6  186.25  101.5  38.5   74.50   26              0
# 11   1.0812     90.9  216.00  103.6  39.4   76.00   27              0
# 12   1.0513     91.6  180.50  102.0  38.4   69.50   32              1
# 13   1.0505    101.8  205.25  104.1  39.4   71.25   30              1
# 14   1.0484     96.4  187.75  101.3  40.5   69.50   35              1
# 15   1.0512     92.8  162.75   99.1  36.4   66.00   35              1
# 16   1.0333     96.4  195.75  101.9  38.9   71.00   34              2
# 17   1.0468     97.5  209.25  107.6  42.1   71.00   32              2
# 18   1.0622     89.6  183.75  106.8  38.0   67.75   28              1
# 19   1.0610    100.5  211.75  106.2  40.0   73.50   33              1
# 20   1.0551     95.9  179.00  103.3  39.1   68.00   28              1
# 21   1.0640     98.8  200.50  111.4  41.3   69.75   28              1
# 22   1.0631     76.4  140.25   86.0  33.9   68.25   31              1
# 23   1.0584     80.0  148.75   86.7  35.5   70.00   32              1
# 24   1.0668     76.3  151.25   90.2  34.5   67.75   28              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Density        252 non-null    float64
#  1   Abdomen        252 non-null    float64
#  2   Weight         252 non-null    float64
#  3   Chest          252 non-null    float64
#  4   Neck           252 non-null    float64
#  5   Height         252 non-null    float64
#  6   Age            252 non-null    int64
#  7   BodyFat_class  252 non-null    int64
# dtypes: float64(6), int64(2)
# memory usage: 15.9 KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# **sns.pairplot** is a function in the seaborn library in Python that is used to plot pairwise relationships between multiple variables in a dataset. The resulting plot is a grid of scatterplots, with each variable plotted against every other variable.

# %%
# Now check columns
print(df.columns.tolist())
# Out:
# ['Density', 'Abdomen', 'Weight', 'Chest', 'Neck', 'Height', 'Age', 'BodyFat_class']

# %%
sns.pairplot(df, hue='BodyFat_class')
plt.show()

# %%
y =df['BodyFat_class']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Data Matrix**

# %%
X = df.drop(columns=['BodyFat_class'])
X.head(10)
# Out:
#    Density  Abdomen  Weight  Chest  Neck  Height  Age
# 0   1.0708     85.2  154.25   93.1  36.2   67.75   23
# 1   1.0853     83.0  173.25   93.6  38.5   72.25   22
# 2   1.0414     87.9  154.00   95.8  34.0   66.25   22
# 3   1.0751     86.4  184.75  101.8  37.4   72.25   26
# 4   1.0340    100.0  184.25   97.3  34.4   71.25   24
# 5   1.0502     94.4  210.25  104.5  39.0   74.75   24
# 6   1.0549     90.7  181.00  105.1  36.4   69.75   26
# 7   1.0704     88.5  176.00   99.6  37.8   72.50   25
# 8   1.0900     82.5  191.00  100.9  38.1   74.00   25
# 9   1.0722     88.6  198.25   99.6  42.1   73.50   23

# %%
X.describe().transpose()
# Out:
#          count        mean        std      min       25%       50%       75%  \
# Density  252.0    1.055574   0.019031    0.995    1.0414    1.0549    1.0704
# Abdomen  252.0   92.555952  10.783077   69.400   84.5750   90.9500   99.3250
# Weight   252.0  178.924405  29.389160  118.500  159.0000  176.5000  197.0000
# Chest    252.0  100.824206   8.430476   79.300   94.3500   99.6500  105.3750
# Neck     252.0   37.992063   2.430913   31.100   36.4000   38.0000   39.4250
# Height   252.0   70.148810   3.662856   29.500   68.2500   70.0000   72.2500
# Age      252.0   44.884921  12.602040   22.000   35.7500   43.0000   54.0000
#
#               max
# Density    1.1089
# Abdomen  148.1000
# Weight   363.1500
# Chest    136.2000
# Neck      51.2000
# Height    77.7500
# Age       81.0000

# %% [markdown]
# **Standardize the Data**

# %%
Xs = StandardScaler().fit_transform(X)
Xcols = X.columns
X = pd.DataFrame(Xs)
X.columns = Xcols
X.head(10)
# Out:
#     Density   Abdomen    Weight     Chest      Neck    Height       Age
# 0  0.801647 -0.683533 -0.841246 -0.918048 -0.738665 -0.656205 -1.740073
# 1  1.565061 -0.887963 -0.193462 -0.858621  0.209365  0.574790 -1.819583
# 2 -0.746240 -0.432643 -0.849769 -0.597144 -1.645475 -1.066536 -1.819583
# 3  1.028039 -0.572026  0.198617  0.115976 -0.244041  0.574790 -1.501543
# 4 -1.135844  0.691719  0.181570 -0.418864 -1.480601  0.301235 -1.660563
# 5 -0.282927  0.171353  1.068011  0.436880  0.415458  1.258676 -1.660563
# 6 -0.035476 -0.172460  0.070765  0.508192 -0.656227 -0.109096 -1.501543
# 7  0.780587 -0.376889 -0.099704 -0.145501 -0.079166  0.643178 -1.581053
# 8  1.812512 -0.934424  0.411704  0.009008  0.044490  1.053510 -1.581053
# 9  0.875356 -0.367597  0.658884 -0.145501  1.693237  0.916733 -1.740073

# %%
X.describe().transpose()
# Out:
#          count          mean      std        min       25%       50%  \
# Density  252.0  5.688571e-15  1.00199  -3.189163 -0.746240 -0.035476
# Abdomen  252.0  3.313046e-16  1.00199  -2.151708 -0.741610 -0.149229
# Weight   252.0  2.819614e-16  1.00199  -2.060102 -0.679300 -0.082657
# Chest    252.0 -5.639228e-17  1.00199  -2.558224 -0.769481 -0.139558
# Neck     252.0 -8.247371e-16  1.00199  -2.840817 -0.656227  0.003271
# Height   252.0  1.480297e-15  1.00199 -11.119658 -0.519428 -0.040707
# Age      252.0  2.220446e-16  1.00199  -1.819583 -0.726319 -0.149870
#
#               75%       max
# Density  0.780587  2.807582
# Abdomen  0.628997  5.161290
# Weight   0.616267  6.280963
# Chest    0.540877  4.204531
# Neck     0.590637  5.444135
# Height   0.574790  2.079339
# Age      0.724741  2.871515

# %% [markdown]
# **Observations and variables**

# %%
observations = list(df.index)
variables = list(df.columns)

# %% [markdown]
# **Box and Whisker Plots**

# %%
ax = plt.figure()
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
# Use swarmplot() or stripplot to show the datapoints on top of the boxes:
#plt. figure()
ax = plt.figure()
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# **Correlation Matrix**

# %%
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.5, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0);

#X.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
#sns.clustermap(X.corr(), annot=True, fmt='.2f')

# %% [markdown]
# ##**Applying PCA**

# %%
pca = PCA()
Z = pca.fit_transform(X)

# 1(Rosa)->0,  2(Kama)->1, 3(Canadian)->2
idx_Rosa = np.where(y == 0)
idx_Kana = np.where(y == 1)
idx_Canadian = np.where(y == 2)

plt. figure()
plt.scatter(Z[idx_Rosa,0], Z[idx_Rosa,1], c='r', label='Rosa')
plt.scatter(Z[idx_Kana,0], Z[idx_Kana,1], c='g', label='Kana')
plt.scatter(Z[idx_Canadian,0], Z[idx_Canadian,1], c='b', label='Canadian')
plt.legend()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
# Out:
# Text(0, 0.5, '$Z_2$')

# %% [markdown]
# **Eigenvectors**

# %%
A = pca.components_.T

plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')

# %%
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %% [markdown]
# **Scree plot**

# %%
#Eigenvalues
Lambda = pca.explained_variance_

#Scree plot
x = np.arange(len(Lambda)) + 1
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
# Out:
# Text(0, 0.5, 'Explained variance')

# %% [markdown]
# **Explained Variance**

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# **Biplot**

# %%
# 0,1 denote PC1 and PC2; change values for other PCs
A1 = A[:,0]
A2 = A[:,1]
Z1 = Z[:,0]
Z2 = Z[:,1]

plt.figure()
plt.xlabel('$Z_1$')
plt.ylabel('$Z_2$')
for i in range(len(A1)):
# arrows project features as vectors onto PC axes
  plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
  plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

plt.scatter(Z[idx_Rosa,0], Z[idx_Rosa,1], c='r', label='Rosa')
plt.scatter(Z[idx_Kana,0], Z[idx_Kana,1], c='g', label='Kana')
plt.scatter(Z[idx_Canadian,0], Z[idx_Canadian,1], c='b', label='Canadian')
plt.legend(loc='upper left')

# %% [markdown]
# ##**Using PCA Library**

# %%
# !pip install pca
# Out:
# Requirement already satisfied: pca in /usr/local/lib/python3.11/dist-packages (2.0.9)
# Requirement already satisfied: datazets in /usr/local/lib/python3.11/dist-packages (from pca) (1.1.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from pca) (0.14.4)
# Requirement already satisfied: matplotlib in /root/.local/lib/python3.11/site-packages (from pca) (3.7.5)
# Requirement already satisfied: numpy in /root/.local/lib/python3.11/site-packages (from pca) (1.26.4)
# Requirement already satisfied: scikit-learn in /root/.local/lib/python3.11/site-packages (from pca) (1.4.2)
# Requirement already satisfied: scipy in /root/.local/lib/python3.11/site-packages (from pca) (1.11.4)
# Requirement already satisfied: colourmap>=1.1.19 in /usr/local/lib/python3.11/dist-packages (from pca) (1.1.20)
# Requirement already satisfied: pandas in /root/.local/lib/python3.11/site-packages (from pca) (2.1.4)
# Requirement already satisfied: scatterd>=1.3.7 in /usr/local/lib/python3.11/dist-packages (from pca) (1.3.7)
# Requirement already satisfied: adjusttext in /usr/local/lib/python3.11/dist-packages (from pca) (1.3.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from scatterd>=1.3.7->pca) (0.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from datazets->pca) (2.32.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pca) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /root/.local/lib/python3.11/site-packages (from scikit-learn->pca) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->pca) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->pca) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pca) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->datazets->pca) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->datazets->pca) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->datazets->pca) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->datazets->pca) (2025.1.31)

# %%
from pca import pca
# Initialize and keep all PCs
model = pca(n_components=0.85)
# Fit transform
out = model.fit_transform(X)
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [85.0%] explained variance using the [7] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [3] that covers the [85.00%] explained variance.
# [pca] >The PCA reduction is performed on the [7] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[3]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %% [markdown]
# **Principal Components**

# %%
out['PC']
# Out:
#           PC1       PC2       PC3
# 0   -2.000885 -0.641705  1.462665
# 1   -1.552530 -2.065771  0.614401
# 2   -1.577168  0.247193  2.152866
# 3   -0.719823 -1.679265  0.617841
# 4   -0.119383 -0.593818  1.443635
# ..        ...       ...       ...
# 247 -2.519423  1.933585 -1.343494
# 248  2.681310  1.676967 -1.171837
# 249  2.259536  2.503324 -0.551283
# 250  1.691138  1.440638 -1.438460
# 251  3.090621  1.660778 -1.292874
#
# [252 rows x 3 columns]

# %% [markdown]
# **Scatter plot**

# %%
model.scatter(label=True, legend=False)
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [95.59%] of the variance'}, xlabel='PC1 (59.1% expl.var)', ylabel='PC2 (19.2% expl.var)'>)

# %% [markdown]
# **Eigenvectors**

# %%
A = out['loadings'].T

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.02, s=variables[i],
          fontdict=dict(color='red',size=10),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %% [markdown]
# **Scree Plot**

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
plt.show()

# %% [markdown]
# **Explained Variance Plot**

# %%
model.plot();

# %% [markdown]
# **Biplot**
#
# A biplot is a graphical representation of multivariate data that displays both observations and variables simultaneously in a single plot. Each observation is represented as a point in a two-dimensional plot, while the variables are represented as arrows or vectors that point in the direction of the greatest variation in the data. The length of the vector indicates the magnitude of the variable, while the angle between two vectors reflects their correlation.

# %%
model.biplot(label=False, legend=False)
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# [scatterd]> WARNING use the standardized verbose status. The status [1-6] will be deprecated in future versions.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '3 Principal Components explain [95.59%] of the variance'}, xlabel='PC1 (59.1% expl.var)', ylabel='PC2 (19.2% expl.var)'>)

# %% [markdown]
# #**Multiclass Classification with PyCaret**
#
# Multiclass classification is a supervised machine learning technique where the goal is to classify instances into one of three or more classes. (Classifying instances into one of two classes is called Binary Classification).

# %% [markdown]
# **Data Splitting**
#
# In order to demonstrate the predict_model() function on unseen data, a sample of 21 observations has been withheld from the original dataset to be used for predictions. This should not be confused with a train/test split as this particular split is performed to simulate a real life scenario. Another way to think about this is that these 21 records were not available at the time when the machine learning experiment was performed.

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (227, 8)
# Unseen Data For Predictions: (25, 8)

# %% [markdown]
# **Setting up the Environment in PyCaret**
#
# The **setup()** function initializes the environment in pycaret and creates the transformation pipeline to prepare the data for modeling and deployment. setup() must be called before executing any other function in pycaret. It takes two mandatory parameters: a pandas dataframe and the name of the target column. All other parameters are optional and are used to customize the pre-processing pipeline.
#
# When setup() is executed, PyCaret's inference algorithm will automatically infer the data types for all features based on certain properties. The data type should be inferred correctly but this is not always the case. To account for this, PyCaret displays a table containing the features and their inferred data types after setup() is executed. If all of the data types are correctly identified enter can be pressed to continue or quit can be typed to end the expriment. Ensuring that the data types are correct is of fundamental importance in PyCaret as it automatically performs a few pre-processing tasks which are imperative to any machine learning experiment. These tasks are performed differently for each data type which means it is very important for them to be correctly configured.

# %%
from pycaret.classification import *
clf = setup(data=data, target='BodyFat_class', train_size=0.7, session_id=123)
# Out:
# <style type="text/css">
# #T_4523b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4523b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4523b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4523b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4523b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4523b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4523b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4523b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4523b_row1_col1" class="data row1 col1" >BodyFat_class</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4523b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4523b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4523b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4523b_row3_col1" class="data row3 col1" >(227, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4523b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4523b_row4_col1" class="data row4 col1" >(227, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4523b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4523b_row5_col1" class="data row5 col1" >(158, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4523b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4523b_row6_col1" class="data row6 col1" >(69, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4523b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4523b_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4523b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4523b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4523b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4523b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4523b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4523b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4523b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4523b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4523b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4523b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4523b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4523b_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4523b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4523b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4523b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4523b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4523b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4523b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4523b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4523b_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4523b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4523b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4523b_row18_col1" class="data row18 col1" >609e</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Once the setup has been succesfully executed it prints the information grid which contains several important pieces of information. Most of the information is related to the pre-processing pipeline which is constructed when setup() is executed. The majority of these features are out of scope for the purposes of this tutorial however a few important things to note at this stage include:
#
# * **session_id** : A pseduo-random number distributed as a seed in all functions for later reproducibility. If no session_id is passed, a random number is automatically generated that is distributed to all functions. In this experiment, the session_id is set as 123 for later reproducibility.
#
# * **Target Type** : Binary or Multiclass. The Target type is automatically detected and shown. There is no difference in how the experiment is performed for Binary or Multiclass problems. All functionalities are identical.
#
# * **Label Encoded** : When the Target variable is of type string (i.e. 'Yes' or 'No') instead of 1 or 0, it automatically encodes the label into 1 and 0 and displays the mapping (0 : No, 1 : Yes) for reference.
#
# * **Original Data** : Displays the original shape of the dataset. In this experiment (189, 8) means 189 samples and 8 features including the class column.
#
# * **Missing Values** : When there are missing values in the original data this will show as True. For this experiment there are no missing values in the dataset.
#
# * **Numeric Features** : The number of features inferred as numeric. In this dataset, 7 out of 8 features are inferred as numeric.
#
# * **Categorical Features** : The number of features inferred as categorical. In this dataset, there are no categorical features.
#
# * **Transformed Train Set** : Displays the shape of the transformed training set. Notice that the original shape of (189, 8) is transformed into (132, 7) for the transformed train set.
#
# * **Transformed Test Set** : Displays the shape of the transformed test/hold-out set. There are 57 samples in test/hold-out set. This split is based on the default value of 70/30 that can be changed using the train_size parameter in setup.
#
# Notice how a few tasks that are imperative to perform modeling are automatically handled such as missing value imputation, categorical encoding etc. Most of the parameters in setup() are optional and used for customizing the pre-processing pipeline.

# %% [markdown]
# **Comparing all Machine Learning Models**

# %%
 #show the best model and their statistics
 best_model = compare_models()
# Out:
# <style type="text/css">
# #T_715c0 th {
#   text-align: left;
# }
# #T_715c0_row0_col0, #T_715c0_row0_col2, #T_715c0_row1_col0, #T_715c0_row1_col1, #T_715c0_row1_col2, #T_715c0_row1_col3, #T_715c0_row1_col4, #T_715c0_row1_col5, #T_715c0_row1_col6, #T_715c0_row1_col7, #T_715c0_row2_col0, #T_715c0_row2_col1, #T_715c0_row2_col2, #T_715c0_row2_col3, #T_715c0_row2_col4, #T_715c0_row2_col5, #T_715c0_row2_col6, #T_715c0_row2_col7, #T_715c0_row3_col0, #T_715c0_row3_col1, #T_715c0_row3_col3, #T_715c0_row3_col4, #T_715c0_row3_col5, #T_715c0_row3_col6, #T_715c0_row3_col7, #T_715c0_row4_col0, #T_715c0_row4_col1, #T_715c0_row4_col2, #T_715c0_row4_col3, #T_715c0_row4_col4, #T_715c0_row4_col5, #T_715c0_row4_col6, #T_715c0_row4_col7, #T_715c0_row5_col0, #T_715c0_row5_col1, #T_715c0_row5_col2, #T_715c0_row5_col3, #T_715c0_row5_col4, #T_715c0_row5_col5, #T_715c0_row5_col6, #T_715c0_row5_col7, #T_715c0_row6_col0, #T_715c0_row6_col1, #T_715c0_row6_col2, #T_715c0_row6_col3, #T_715c0_row6_col4, #T_715c0_row6_col5, #T_715c0_row6_col6, #T_715c0_row6_col7, #T_715c0_row7_col0, #T_715c0_row7_col1, #T_715c0_row7_col2, #T_715c0_row7_col3, #T_715c0_row7_col4, #T_715c0_row7_col5, #T_715c0_row7_col6, #T_715c0_row7_col7, #T_715c0_row8_col0, #T_715c0_row8_col1, #T_715c0_row8_col2, #T_715c0_row8_col3, #T_715c0_row8_col4, #T_715c0_row8_col5, #T_715c0_row8_col6, #T_715c0_row8_col7, #T_715c0_row9_col0, #T_715c0_row9_col1, #T_715c0_row9_col2, #T_715c0_row9_col3, #T_715c0_row9_col4, #T_715c0_row9_col5, #T_715c0_row9_col6, #T_715c0_row9_col7, #T_715c0_row10_col0, #T_715c0_row10_col1, #T_715c0_row10_col2, #T_715c0_row10_col3, #T_715c0_row10_col4, #T_715c0_row10_col5, #T_715c0_row10_col6, #T_715c0_row10_col7, #T_715c0_row11_col0, #T_715c0_row11_col1, #T_715c0_row11_col2, #T_715c0_row11_col3, #T_715c0_row11_col4, #T_715c0_row11_col5, #T_715c0_row11_col6, #T_715c0_row11_col7, #T_715c0_row12_col0, #T_715c0_row12_col1, #T_715c0_row12_col2, #T_715c0_row12_col3, #T_715c0_row12_col4, #T_715c0_row12_col5, #T_715c0_row12_col6, #T_715c0_row12_col7, #T_715c0_row13_col0, #T_715c0_row13_col1, #T_715c0_row13_col2, #T_715c0_row13_col3, #T_715c0_row13_col4, #T_715c0_row13_col5, #T_715c0_row13_col6, #T_715c0_row13_col7, #T_715c0_row14_col0, #T_715c0_row14_col1, #T_715c0_row14_col2, #T_715c0_row14_col3, #T_715c0_row14_col4, #T_715c0_row14_col5, #T_715c0_row14_col6, #T_715c0_row14_col7 {
#   text-align: left;
# }
# #T_715c0_row0_col1, #T_715c0_row0_col3, #T_715c0_row0_col4, #T_715c0_row0_col5, #T_715c0_row0_col6, #T_715c0_row0_col7, #T_715c0_row3_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_715c0_row0_col8, #T_715c0_row1_col8, #T_715c0_row2_col8, #T_715c0_row3_col8, #T_715c0_row4_col8, #T_715c0_row5_col8, #T_715c0_row6_col8, #T_715c0_row7_col8, #T_715c0_row9_col8, #T_715c0_row10_col8, #T_715c0_row11_col8, #T_715c0_row12_col8, #T_715c0_row13_col8, #T_715c0_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_715c0_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_715c0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_715c0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_715c0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_715c0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_715c0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_715c0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_715c0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_715c0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_715c0_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_715c0_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_715c0_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_715c0_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_715c0_row0_col1" class="data row0 col1" >0.9688</td>
#       <td id="T_715c0_row0_col2" class="data row0 col2" >0.9827</td>
#       <td id="T_715c0_row0_col3" class="data row0 col3" >0.9688</td>
#       <td id="T_715c0_row0_col4" class="data row0 col4" >0.9738</td>
#       <td id="T_715c0_row0_col5" class="data row0 col5" >0.9686</td>
#       <td id="T_715c0_row0_col6" class="data row0 col6" >0.9531</td>
#       <td id="T_715c0_row0_col7" class="data row0 col7" >0.9557</td>
#       <td id="T_715c0_row0_col8" class="data row0 col8" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_715c0_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_715c0_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_715c0_row1_col1" class="data row1 col1" >0.9625</td>
#       <td id="T_715c0_row1_col2" class="data row1 col2" >0.9904</td>
#       <td id="T_715c0_row1_col3" class="data row1 col3" >0.9625</td>
#       <td id="T_715c0_row1_col4" class="data row1 col4" >0.9702</td>
#       <td id="T_715c0_row1_col5" class="data row1 col5" >0.9628</td>
#       <td id="T_715c0_row1_col6" class="data row1 col6" >0.9438</td>
#       <td id="T_715c0_row1_col7" class="data row1 col7" >0.9474</td>
#       <td id="T_715c0_row1_col8" class="data row1 col8" >0.1840</td>
#     </tr>
#     <tr>
#       <th id="T_715c0_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_715c0_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_715c0_row2_col1" class="data row2 col1" >0.9625</td>
#       <td id="T_715c0_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_715c0_row2_col3" class="data row2 col3" >0.9625</td>
#       <td id="T_715c0_row2_col4" class="data row2 col4" >0.9698</td>
#       <td id="T_715c0_row2_col5" class="data row2 col5" >0.9618</td>
#       <td id="T_715c0_row2_col6" class="data row2 col6" >0.9435</td>
#       <td id="T_715c0_row2_col7" class="data row2 col7" >0.9476</td>
#       <td id="T_715c0_row2_col8" class="data row2 col8" >0.1080</td>
#     </tr>
#     <tr>
#       <th id="T_715c0_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_715c0_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_715c0_row3_col1" class="data row3 col1" >0.9625</td>
#       <td id="T_715c0_row3_col2" class="data row3 col2" >0.9914</td>
#       <td id="T_715c0_row3_col3" class="data row3 col3" >0.9625</td>
#       <td id="T_715c0_row3_col4" class="data row3 col4" >0.9701</td>
#       <td id="T_715c0_row3_col5" class="data row3 col5" >0.9622</td>
#       <td id="T_715c0_row3_col6" class="data row3 col6" >0.9439</td>
#       <td id="T_715c0_row3_col7" class="data row3 col7" >0.9479</td>
#       <td id="T_715c0_row3_col8" class="data row3 col8" >0.2260</td>
#     </tr>
#     <tr>
#       <th id="T_715c0_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_715c0_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_715c0_row4_col1" class="data row4 col1" >0.9562</td>
#       <td id="T_715c0_row4_col2" class="data row4 col2" >0.9673</td>
#       <td id="T_715c0_row4_col3" class="data row4 col3" >0.9562</td>
#       <td id="T_715c0_row4_col4" class="data row4 col4" >0.9646</td>
#       <td id="T_715c0_row4_col5" class="data row4 col5" >0.9555</td>
#       <td id="T_715c0_row4_col6" class="data row4 col6" >0.9341</td>
#       <td id="T_715c0_row4_col7" class="data row4 col7" >0.9388</td>
#       <td id="T_715c0_row4_col8" class="data row4 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_715c0_level0_row5" class="row_heading level0 row5" >gbc</th>
#       <td id="T_715c0_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_715c0_row5_col1" class="data row5 col1" >0.9500</td>
#       <td id="T_715c0_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_715c0_row5_col3" class="data row5 col3" >0.9500</td>
#       <td id="T_715c0_row5_col4" class="data row5 col4" >0.959
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
best_model
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cpu', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=-1,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# **Create a Model**
#
# create_model is the most granular function in PyCaret and is often the foundation behind most of the PyCaret functionalities. As the name suggests this function trains and evaluates a model using cross validation that can be set with fold parameter. The output prints a score grid that shows Accuracy, Recall, Precision, F1, Kappa and MCC by fold.
#
# For the remaining part of this tutorial, we will work with the below models as our candidate models. The selections are for illustration purposes only and do not necessarily mean they are the top performing or ideal for this type of data.
#
# * Decision Tree Classifier ('dt')
# * K Neighbors Classifier ('knn')
# * Logistic Regression ('lr')
#
# There are many classifiers available in the model library of PyCaret. Please view the create_model() docstring for the list of all available models.

# %% [markdown]
# **Create Decision Tree Classifier**

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_2f0f4_row10_col0, #T_2f0f4_row10_col1, #T_2f0f4_row10_col2, #T_2f0f4_row10_col3, #T_2f0f4_row10_col4, #T_2f0f4_row10_col5, #T_2f0f4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2f0f4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f0f4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2f0f4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2f0f4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2f0f4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2f0f4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2f0f4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2f0f4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f0f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f0f4_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_2f0f4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_2f0f4_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_2f0f4_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_2f0f4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_2f0f4_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_2f0f4_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f0f4_row1_col0" class="data row1 col0" >0.9375</td>
#       <td id="T_2f0f4_row1_col1" class="data row1 col1" >0.9545</td>
#       <td id="T_2f0f4_row1_col2" class="data row1 col2" >0.9375</td>
#       <td id="T_2f0f4_row1_col3" class="data row1 col3" >0.9479</td>
#       <td id="T_2f0f4_row1_col4" class="data row1 col4" >0.9369</td>
#       <td id="T_2f0f4_row1_col5" class="data row1 col5" >0.9059</td>
#       <td id="T_2f0f4_row1_col6" class="data row1 col6" >0.9113</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f0f4_row2_col0" class="data row2 col0" >0.9375</td>
#       <td id="T_2f0f4_row2_col1" class="data row2 col1" >0.9545</td>
#       <td id="T_2f0f4_row2_col2" class="data row2 col2" >0.9375</td>
#       <td id="T_2f0f4_row2_col3" class="data row2 col3" >0.9479</td>
#       <td id="T_2f0f4_row2_col4" class="data row2 col4" >0.9375</td>
#       <td id="T_2f0f4_row2_col5" class="data row2 col5" >0.9064</td>
#       <td id="T_2f0f4_row2_col6" class="data row2 col6" >0.9118</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f0f4_row3_col0" class="data row3 col0" >0.9375</td>
#       <td id="T_2f0f4_row3_col1" class="data row3 col1" >0.9545</td>
#       <td id="T_2f0f4_row3_col2" class="data row3 col2" >0.9375</td>
#       <td id="T_2f0f4_row3_col3" class="data row3 col3" >0.9479</td>
#       <td id="T_2f0f4_row3_col4" class="data row3 col4" >0.9369</td>
#       <td id="T_2f0f4_row3_col5" class="data row3 col5" >0.9059</td>
#       <td id="T_2f0f4_row3_col6" class="data row3 col6" >0.9113</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f0f4_row4_col0" class="data row4 col0" >0.9375</td>
#       <td id="T_2f0f4_row4_col1" class="data row4 col1" >0.9545</td>
#       <td id="T_2f0f4_row4_col2" class="data row4 col2" >0.9375</td>
#       <td id="T_2f0f4_row4_col3" class="data row4 col3" >0.9479</td>
#       <td id="T_2f0f4_row4_col4" class="data row4 col4" >0.9375</td>
#       <td id="T_2f0f4_row4_col5" class="data row4 col5" >0.9064</td>
#       <td id="T_2f0f4_row4_col6" class="data row4 col6" >0.9118</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f0f4_row5_col0" class="data row5 col0" >0.9375</td>
#       <td id="T_2f0f4_row5_col1" class="data row5 col1" >0.9545</td>
#       <td id="T_2f0f4_row5_col2" class="data row5 col2" >0.9375</td>
#       <td id="T_2f0f4_row5_col3" class="data row5 col3" >0.9479</td>
#       <td id="T_2f0f4_row5_col4" class="data row5 col4" >0.9375</td>
#       <td id="T_2f0f4_row5_col5" class="data row5 col5" >0.9064</td>
#       <td id="T_2f0f4_row5_col6" class="data row5 col6" >0.9118</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f0f4_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_2f0f4_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_2f0f4_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_2f0f4_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_2f0f4_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_2f0f4_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_2f0f4_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2f0f4_row7_col0" class="data row7 col0" >0.8750</td>
#       <td id="T_2f0f4_row7_col1" class="data row7 col1" >0.9000</td>
#       <td id="T_2f0f4_row7_col2" class="data row7 col2" >0.8750</td>
#       <td id="T_2f0f4_row7_col3" class="data row7 col3" >0.9062</td>
#       <td id="T_2f0f4_row7_col4" class="data row7 col4" >0.8683</td>
#       <td id="T_2f0f4_row7_col5" class="data row7 col5" >0.8095</td>
#       <td id="T_2f0f4_row7_col6" class="data row7 col6" >0.8298</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2f0f4_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_2f0f4_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_2f0f4_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_2f0f4_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_2f0f4_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_2f0f4_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_2f0f4_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2f0f4_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_2f0f4_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_2f0f4_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_2f0f4_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_2f0f4_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_2f0f4_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_2f0f4_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2f0f4_row10_col0" class="data row10 col0" >0.9562</td>
#       <td id="T_2f0f4_row10_col1" class="data row10 col1" >0.9673</td>
#       <td id="T_2f0f4_row10_col2" class="data row10 col2" >0.9562</td>
#       <td id="T_2f0f4_row10_col3" class="data row10 col3" >0.9646</td>
#       <td id="T_2f0f4_row10_col4" class="data row10 col4" >0.9555</td>
#       <td id="T_2f0f4_row10_col5" class="data row10 col5" >0.9341</td>
#       <td id="T_2f0f4_row10_col6" class="data row10 col6" >0.9388</td>
#     </tr>
#     <tr>
#       <th id="T_2f0f4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2f0f4_row11_col0" class="data row11 col0" >0.0400</td>
#       <td id="T_2f0f4_row11_col1" class="data row11 col1" >0.0310</td>
#       <td id="T_2f0f4_row11_col2" class="data row11 col2" >0.0400</td>
#       <td id="T_2f0f4_row11_col3" class="data row11 col3" >0.0313</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#trained model object is stored in the variable 'dt'.
dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %% [markdown]
# **Tune a Model:** How to automatically tune the hyper-parameters of a multiclass model. When a model is created using the create_model() function it uses the default hyperparameters. In order to tune hyperparameters, the tune_model() function is used. The tune_model() function is a random grid search of hyperparameters over a pre-defined search space. By default, it is set to optimize Accuracy but this can be changed using optimize parameter. This function automatically tunes the hyperparameters of a model on a pre-defined search space and scores it using stratified cross validation. The output prints a score grid that shows Accuracy, AUC, Recall, Precision, F1 and Kappa by fold.

# %% [markdown]
# **Tune Decision Tree Model**

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_a4da0_row10_col0, #T_a4da0_row10_col1, #T_a4da0_row10_col2, #T_a4da0_row10_col3, #T_a4da0_row10_col4, #T_a4da0_row10_col5, #T_a4da0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a4da0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4da0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a4da0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a4da0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a4da0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a4da0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a4da0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a4da0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4da0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4da0_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_a4da0_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a4da0_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_a4da0_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_a4da0_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_a4da0_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_a4da0_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_
td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
#tuned model object is stored in the variable 'tuned_dt'.
tuned_dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0001, min_samples_leaf=4,
#                        min_samples_split=10, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %% [markdown]
# **Evaluate Decision Tree Model**

# %% [markdown]
# How to analyze model performance using various plots

# %%
evaluate_model(tuned_dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Create K Neighbors Model**

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_8f24c_row10_col0, #T_8f24c_row10_col1, #T_8f24c_row10_col2, #T_8f24c_row10_col3, #T_8f24c_row10_col4, #T_8f24c_row10_col5, #T_8f24c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8f24c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f24c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8f24c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8f24c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8f24c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8f24c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8f24c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8f24c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f24c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f24c_row0_col0" class="data row0 col0" >0.6250</td>
#       <td id="T_8f24c_row0_col1" class="data row0 col1" >0.8241</td>
#       <td id="T_8f24c_row0_col2" class="data row0 col2" >0.6250</td>
#       <td id="T_8f24c_row0_col3" class="data row0 col3" >0.6548</td>
#       <td id="T_8f24c_row0_col4" class="data row0 col4" >0.6250</td>
#       <td id="T_8f24c_row0_col5" class="data row0 col5" >0.4353</td>
#       <td id="T_8f24c_row0_col6" class="data row0 col6" >0.4459</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8f24c_row1_col0" class="data row1 col0" >0.6250</td>
#       <td id="T_8f24c_row1_col1" class="data row1 col1" >0.7290</td>
#       <td id="T_8f24c_row1_col2" class="data row1 col2" >0.6250</td>
#       <td id="T_8f24c_row1_col3" class="data row1 col3" >0.6652</td>
#       <td id="T_8f24c_row1_col4" class="data row1 col4" >0.6360</td>
#       <td id="T_8f24c_row1_col5" class="data row1 col5" >0.4386</td>
#       <td id="T_8f24c_row1_col6" class="data row1 col6" >0.4465</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8f24c_row2_col0" class="data row2 col0" >0.8125</td>
#       <td id="T_8f24c_row2_col1" class="data row2 col1" >0.8915</td>
#       <td id="T_8f24c_row2_col2" class="data row2 col2" >0.8125</td>
#       <td id="T_8f24c_row2_col3" class="data row2 col3" >0.8333</td>
#       <td id="T_8f24c_row2_col4" class="data row2 col4" >0.8182</td>
#       <td id="T_8f24c_row2_col5" class="data row2 col5" >0.7193</td>
#       <td id="T_8f24c_row2_col6" class="data row2 col6" >0.7235</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8f24c_row3_col0" class="data row3 col0" >0.8125</td>
#       <td id="T_8f24c_row3_col1" class="data row3 col1" >0.9358</td>
#       <td id="T_8f24c_row3_col2" class="data row3 col2" >0.8125</td>
#       <td id="T_8f24c_row3_col3" class="data row3 col3" >0.8438</td>
#       <td id="T_8f24c_row3_col4" class="data row3 col4" >0.8114</td>
#       <td id="T_8f24c_row3_col5" class="data row3 col5" >0.7209</td>
#       <td id="T_8f24c_row3_col6" class="data row3 col6" >0.7337</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8f24c_row4_col0" class="data row4 col0" >0.6250</td>
#       <td id="T_8f24c_row4_col1" class="data row4 col1" >0.7926</td>
#       <td id="T_8f24c_row4_col2" class="data row4 col2" >0.6250</td>
#       <td id="T_8f24c_row4_col3" class="data row4 col3" >0.5982</td>
#       <td id="T_8f24c_row4_col4" class="data row4 col4" >0.5979</td>
#       <td id="T_8f24c_row4_col5" class="data row4 col5" >0.4419</td>
#       <td id="T_8f24c_row4_col6" class="data row4 col6" >0.4524</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8f24c_row5_col0" class="data row5 col0" >0.5625</td>
#       <td id="T_8f24c_row5_col1" class="data row5 col1" >0.6520</td>
#       <td id="T_8f24c_row5_col2" class="data row5 col2" >0.5625</td>
#       <td id="T_8f24c_row5_col3" class="data row5 col3" >0.6562</td>
#       <td id="T_8f24c_row5_col4" class="data row5 col4" >0.5633</td>
#       <td id="T_8f24c_row5_col5" class="data row5 col5" >0.3333</td>
#       <td id="T_8f24c_row5_col6" class="data row5 col6" >0.3484</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8f24c_row6_col0" class="data row6 col0" >0.5625</td>
#       <td id="T_8f24c_row6_col1" class="data row6 col1" >0.6636</td>
#       <td id="T_8f24c_row6_col2" class="data row6 col2" >0.5625</td>
#       <td id="T_8f24c_row6_col3" class="data row6 col3" >0.5354</td>
#       <td id="T_8f24c_row6_col4" class="data row6 col4" >0.5455</td>
#       <td id="T_8f24c_row6_col5" class="data row6 col5" >0.3450</td>
#       <td id="T_8f24c_row6_col6" class="data row6 col6" >0.3471</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8f24c_row7_col0" class="data row7 col0" >0.6875</td>
#       <td id="T_8f24c_row7_col1" class="data row7 col1" >0.7844</td>
#       <td id="T_8f24c_row7_col2" class="data row7 col2" >0.6875</td>
#       <td id="T_8f24c_row7_col3" class="data row7 col3" >0.6815</td>
#       <td id="T_8f24c_row7_col4" class="data row7 col4" >0.6544</td>
#       <td id="T_8f24c_row7_col5" class="data row7 col5" >0.5376</td>
#       <td id="T_8f24c_row7_col6" class="data row7 col6" >0.5604</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8f24c_row8_col0" class="data row8 col0" >0.5333</td>
#       <td id="T_8f24c_row8_col1" class="data row8 col1" >0.8467</td>
#       <td id="T_8f24c_row8_col2" class="data row8 col2" >0.5333</td>
#       <td id="T_8f24c_row8_col3" class="data row8 col3" >0.4333</td>
#       <td id="T_8f24c_row8_col4" class="data row8 col4" >0.4718</td>
#       <td id="T_8f24c_row8_col5" class="data row8 col5" >0.3000</td>
#       <td id="T_8f24c_row8_col6" class="data row8 col6" >0.3198</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8f24c_row9_col0" class="data row9 col0" >0.6667</td>
#       <td id="T_8f24c_row9_col1" class="data row9 col1" >0.8200</td>
#       <td id="T_8f24c_row9_col2" class="data row9 col2" >0.6667</td>
#       <td id="T_8f24c_row9_col3" class="data row9 col3" >0.6722</td>
#       <td id="T_8f24c_row9_col4" class="data row9 col4" >0.6646</td>
#       <td id="T_8f24c_row9_col5" class="data row9 col5" >0.5000</td>
#       <td id="T_8f24c_row9_col6" class="data row9 col6" >0.5034</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8f24c_row10_col0" class="data row10 col0" >0.6512</td>
#       <td id="T_8f24c_row10_col1" class="data row10 col1" >0.7940</td>
#       <td id="T_8f24c_row10_col2" class="data row10 col2" >0.6512</td>
#       <td id="T_8f24c_row10_col3" class="data row10 col3" >0.6574</td>
#       <td id="T_8f24c_row10_col4" class="data row10 col4" >0.6388</td>
#       <td id="T_8f24c_row10_col5" class="data row10 col5" >0.4772</td>
#       <td id="T_8f24c_row10_col6" class="data row10 col6" >0.4881</td>
#     </tr>
#     <tr>
#       <th id="T_8f24c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8f24c_row11_col0" class="data row11 col0" >0.0923</td>
#       <td id="T_8f24c_row11_col1" class="data row11 col1" >0.0869</td>
#       <td id="T_8f24c_row11_col2" class="data row11 col2" >0.0923</td>
#       <td id="T_8f24c_row11_col3" class="data row11 col3" >0.1162</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# **Tune K Neighbors Model**

# %%
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,50,1)})
# Out:
# <style type="text/css">
# #T_4b49e_row10_col0, #T_4b49e_row10_col1, #T_4b49e_row10_col2, #T_4b49e_row10_col3, #T_4b49e_row10_col4, #T_4b49e_row10_col5, #T_4b49e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4b49e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b49e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4b49e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4b49e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4b49e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4b49e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4b49e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4b49e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b49e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b49e_row0_col0" class="data row0 col0" >0.5625</td>
#       <td id="T_4b49e_row0_col1" class="data row0 col1" >0.8051</td>
#       <td id="T_4b49e_row0_col2" class="data row0 col2" >0.5625</td>
#       <td id="T_4b49e_row0_col3" class="data row0 col3" >0.5312</td>
#       <td id="T_4b49e_row0_col4" class="data row0 col4" >0.5143</td>
#       <td id="T_4b49e_row0_col5" class="data row0 col5" >0.3293</td>
#       <td id="T_4b49e_row0_col6" class="data row0 col6" >0.3491</td>
#     </tr>
#     <tr>
#       <th id="T_4b49e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b49e_row1_col0" class="data row1 col0" >0.6875</td>
#       <td id="T_4b49e_row1_col1" class="data row1 col1" >0.7500</td>
#       <td id="T_4b49e_row1_col2" class="data row1 col2" >0.6875</td>
#       <td id="T_4b49e_row1_col3" class="data row1 col3" >0.7188</td>
#       <td id="T_4b49e_row1_col4" class="data row1 col4" >0.6989</td>
#       <td id="T_4b49e_row1_col5" class="data row1 col5" >0.5322</td>
#       <td id="T_4b49e_row1_col6" class="data row1 col6" >0.5353</td>
#     </tr>
#     <tr>
#       <th id="T_4b49e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b49e_row2_col0" class="data row2 col0" >0.6875</td>
#       <td id="T_4b49e_row2_col1" class="data row2 col1" >0.7577</td>
#       <td id="T_4b49e_row2_col2" class="data row2 col2" >0.6875</td>
#       <td id="T_4b49e_row2_col3" class="data row2 col3" >0.7812</td>
#       <td id="T_4b49e_row2_col4" class="data row2 col4" >0.6834</td>
#       <td id="T_4b49e_row2_col5" class="data row2 col5" >0.5294</td>
#       <td id="T_4b49e_row2_col6" class="data row2 col6" >0.5599</td>
#     </tr>
#     <tr>
#       <th id="T_4b49e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b49e_row3_col0" class="data row3 col0" >0.5000</td>
#       <td id="T_4b49e_row3_col1" class="data row3 col1" >0.7591</td>
#       <td id="T_4b49e_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T
row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_3af93_row9_col2" class="data row9 col2" >0.8667</td>
#       <td id="T_3af93_row9_col3" class="data row9 col3" >0.8667</td>
#       <td id="T_3af93_row9_col4" class="data row9 col4" >0.8667</td>
#       <td id="T_3af93_row9_col5" class="data row9 col5" >0.8000</td>
#       <td id="T_3af93_row9_col6" class="data row9 col6" >0.8000</td>
#     </tr>
#     <tr>
#       <th id="T_3af93_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3af93_row10_col0" class="data row10 col0" >0.7096</td>
#       <td id="T_3af93_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_3af93_row10_col2" class="data row10 col2" >0.7096</td>
#       <td id="T_3af93_row10_col3" class="data row10 col3" >0.7417</td>
#       <td id="T_3af93_row10_col4" class="data row10 col4" >0.7050</td>
#       <td id="T_3af93_row10_col5" class="data row10 col5" >0.5644</td>
#       <td id="T_3af93_row10_col6" class="data row10 col6" >0.5816</td>
#     </tr>
#     <tr>
#       <th id="T_3af93_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3af93_row11_col0" class="data row11 col0" >0.1187</td>
#       <td id="T_3af93_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_3af93_row11_col2" class="data row11 col2" >0.1187</td>
#       <td id="T_3af93_row11_col3" class="data row11 col3" >0.1255</td>
#       <td id="
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# **Tune Logistic Regression Model**

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_e4e6d_row10_col0, #T_e4e6d_row10_col1, #T_e4e6d_row10_col2, #T_e4e6d_row10_col3, #T_e4e6d_row10_col4, #T_e4e6d_row10_col5, #T_e4e6d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e4e6d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4e6d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e4e6d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e4e6d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e4e6d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e4e6d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e4e6d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e4e6d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4e6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4e6d_row0_col0" class="data row0 col0" >0.8750</td>
#       <td id="T_e4e6d_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_e4e6d_row0_col2" class="data row0 col2" >0.8750</td>
#       <td id="T_e4e6d_row0_col3" class="data row0 col3" >0.9107</td>
#       <td id="T_e4e6d_row0_col4" class="data row0 col4" >0.8791</td>
#       <td id="T_e4e6d_row0_col5" class="data row0 col5" >0.8129</td>
#       <td id="T_e4e6d_row0_col6" class="data row0 col6" >0.8274</td>
#     </tr>
#     <tr>
#       <th id="T_e4e6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4e6d_row1_col0" class="data row1 col0" >0.6875</td>
#       <td id="T_e4e6d_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_e4e6d_row1_col2" class="data row1 col2" >0.6875</td>
#       <td id="T_e4e6d_row1_col3" class="data row1 col3" >0.8438</td>
#       <td id="T_e4e6d_row1_col4" class="data row1 col4" >0.6869</td>
#       <td id="T_e4e6d_row1_col5" class="data row1 col5" >0.5349</td>
#       <td id="T_e4e6d_row1_col6" class="data row1 col6" >0.6051</td>
#     </tr>
#     <tr>
#       <th id="T_e4e6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4e6d_row2_col0" class="data row2 col0" >0.6875</td>
#       <td id="T_e4e6d_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_e4e6d_row2_col2" class="data row2 col2" >0.6875</td>
#       <td id="T_e4e6d_row2_col3" class="data row2 col3" >0.7656</td>
#       <td id="T_e4e6d_row2_col4" class="data row2 col4" >0.7006</td>
#       <td id="T_e4e6d_row2_col5" class="data row2 col5" >0.5349</td>
#       <td id="T_e4e6d_row2_col6" class="data row2 col6" >0.5578</td>
#     </tr>
#     <tr>
#       <th id="T_e4e6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4e6d_row3_col0" class="data row3 col0" >0.9375</td>
#       <td id="T_e4e6d_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T

#               num_parallel_tree=None, objective='multi:softprob', ...)

# %% [markdown]
# **Evaluate the Best Model**
#
# One way to analyze the performance of models is to use the evaluate_model() function which displays a user interface for all of the available plots for a given model. It internally uses the plot_model() function.

# %%
evaluate_model(tuned_best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# #**Classification + PCA**

# %%
clf_pca = setup(data=df, target='BodyFat_class', train_size=0.7, session_id=123, normalize = True, pca = True, pca_components = 3)
# Out:
# <style type="text/css">
# #T_701c7_row8_col1, #T_701c7_row12_col1, #T_701c7_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_701c7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_701c7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_701c7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_701c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_701c7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_701c7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_701c7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_701c7_row1_col1" class="data row1 col1" >BodyFat_class</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_701c7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_701c7_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_701c7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_701c7_row3_col1" class="data row3 col1" >(252, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_701c7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_701c7_row4_col1" class="data row4 col1" >(252, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_701c7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_701c7_row5_col1" class="data row5 col1" >(176, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_701c7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_701c7_row6_col1" class="data row6 col1" >(76, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_701c7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_701c7_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_701c7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_701c7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_701c7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_701c7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_701c7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_701c7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_701c7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_701c7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_701c7_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_701c7_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_701c7_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_701c7_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_701c7_row14_col0" class="data row14 col0" >PCA</td>
#       <td id="T_701c7_row14_col1" class="data row14 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_701c7_row15_col0" class="data row15 col0" >PCA method</td>
#       <td id="T_701c7_row15_col1" class="data row15 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_701c7_row16_col0" class="data row16 col0" >PCA components</td>
#       <td id="T_701c7_row16_col1" class="data row16 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_701c7_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_701c7_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_701c7_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_701c7_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_701c7_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_701c7_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_701c7_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_701c7_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_701c7_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_701c7_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_701c7_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_701c7_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_701c7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_701c7_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_701c7_row23_col1" class="data row23 col1" >d01f</td>
#     </tr>
#   </tbody>
# </table>

# %%
#show the best model and their statistics
best_model_pca = compare_models()
# Out:
# <style type="text/css">
# #T_d1ec0 th {
#   text-align: left;
# }
# #T_d1ec0_row0_col0, #T_d1ec0_row0_col2, #T_d1ec0_row1_col0, #T_d1ec0_row1_col1, #T_d1ec0_row1_col3, #T_d1ec0_row1_col4, #T_d1ec0_row1_col5, #T_d1ec0_row1_col6, #T_d1ec0_row1_col7, #T_d1ec0_row2_col0, #T_d1ec0_row2_col1, #T_d1ec0_row2_col2, #T_d1ec0_row2_col3, #T_d1ec0_row2_col4, #T_d1ec0_row2_col5, #T_d1ec0_row2_col6, #T_d1ec0_row2_col7, #T_d1ec0_row3_col0, #T_d1ec0_row3_col1, #T_d1ec0_row3_col2, #T_d1ec0_row3_col3, #T_d1ec0_row3_col4, #T_d1ec0_row3_col5, #T_d1ec0_row3_col6, #T_d1ec0_row3_col7, #T_d1ec0_row4_col0, #T_d1ec0_row4_col1, #T_d1ec0_row4_col2, #T_d1ec0_row4_col3, #T_d1ec0_row4_col4, #T_d1ec0_row4_col5, #T_d1ec0_row4_col6, #T_d1ec0_row4_col7, #T_d1ec0_row5_col0, #T_d1ec0_row5_col1, #T_d1ec0_row5_col2, #T_d1ec0_row5_col3, #T_d1ec0_row5_col4, #T_d1ec0_row5_col5, #T_d1ec0_row5_col6, #T_d1ec0_row5_col7, #T_d1ec0_row6_col0, #T_d1ec0_row6_col1, #T_d1ec0_row6_col2, #T_d1ec0_row6_col3, #T_d1ec0_row6_col4, #T_d1ec0_row6_col5, #T_d1ec0_row6_col6, #T_d1ec0_row6_col7, #T_d1ec0_row7_col0, #T_d1ec0_row7_col1, #T_d1ec0_row7_col2, #T_d1ec0_row7_col3, #T_d1ec0_row7_col4, #T_d1ec0_row7_col5, #T_d1ec0_row7_col6, #T_d1ec0_row7_col7, #T_d1ec0_row8_col0, #T_d1ec0_row8_col1, #T_d1ec0_row8_col2, #T_d1ec0_row8_col3, #T_d1ec0_row8_col4, #T_d1ec0_row8_col5, #T_d1ec0_row8_col6, #T_d1ec0_row8_col7, #T_d1ec0_row9_col0, #T_d1ec0_row9_col1, #T_d1ec0_row9_col2, #T_d1ec0_row9_col3, #T_d1ec0_row9_col4, #T_d1ec0_row9_col5, #T_d1ec0_row9_col6, #T_d1ec0_row9_col7, #T_d1ec0_row10_col0, #T_d1ec0_row10_col1, #T_d1ec0_row10_col2, #T_d1ec0_row10_col3, #T_d1ec0_row10_col4, #T_d1ec0_row10_col5, #T_d1ec0_row10_col6, #T_d1ec0_row10_col7, #T_d1ec0_row11_col0, #T_d1ec0_row11_col1, #T_d1ec0_row11_col2, #T_d1ec0_row11_col3, #T_d1ec0_row11_col4, #T_d1ec0_row11_col5, #T_d1ec0_row11_col6, #T_d1ec0_row11_col7, #T_d1ec0_row12_col0, #T_d1ec0_row12_col1, #T_d1ec0_row12_col2, #T_d1ec0_row12_col3, #T_d1ec0_row12_col4, #T_d1ec0_row12_col5, #T_d1ec0_row12_col6, #T_d1ec0_row12_col7, #T_d1ec0_row13_col0, #T_d1ec0_row13_col1, #T_d1ec0_row13_col2, #T_d1ec0_row13_col3, #T_d1ec0_row13_col4, #T_d1ec0_row13_col5, #T_d1ec0_row13_col6, #T_d1ec0_row13_col7, #T_d1ec0_row14_col0, #T_d1ec0_row14_col1, #T_d1ec0_row14_col2, #T_d1ec0_row14_col3, #T_d1ec0_row14_col4, #T_d1ec0_row14_col5, #T_d1ec0_row14_col6, #T_d1ec0_row14_col7 {
#   text-align: left;
# }
# #T_d1ec0_row0_col1, #T_d1ec0_row0_col3, #T_d1ec0_row0_col4, #T_d1ec0_row0_col5, #T_d1ec0_row0_col6, #T_d1ec0_row0_col7, #T_d1ec0_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d1ec0_row0_col8, #T_d1ec0_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_d1ec0_row1_col8, #T_d1ec0_row2_col8, #T_d1ec0_row4_col8, #T_d1ec0_row5_col8, #T_d1ec0_row6_col8, #T_d1ec0_row7_col8, #T_d1ec0_row8_col8, #T_d1ec0_row9_col8, #T_d1ec0_row10_col8, #T_d1ec0_row11_col8, #T_d1ec0_row12_col8, #T_d1ec0_row13_col8, #T_d1ec0_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d1ec0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1ec0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d1ec0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d1ec0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d1ec0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d1ec0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d1ec0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d1ec0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d1ec0_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d1ec0_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1ec0_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_d1ec0_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d1ec0_row0_col1" class="data row0 col1" >0.7948</td>
#       <td id="T_d1ec0_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T
inearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %% [markdown]
# **Evaluate the Best Model**
#
# One way to analyze the performance of models is to use the evaluate_model() function which displays a user interface for all of the available plots for a given model. It internally uses the plot_model() function.

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Note:** The AUC metric is not available for Multiclass classification however the column will still be shown with zero values to maintain consistency between the Binary Classification and Multiclass Classification display grids.

# %% [markdown]
# #**Explainable AI with Shapley values**
#
# Shapley values are a widely used approach from cooperative game theory that come with desirable properties.

# %%
rf_pca = create_model('rf')
# Out:
# <style type="text/css">
# #T_2f634_row10_col0, #T_2f634_row10_col1, #T_2f634_row10_col2, #T_2f634_row10_col3, #T_2f634_row10_col4, #T_2f634_row10_col5, #T_2f634_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2f634" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f634_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2f634_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2f634_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2f634_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2f634_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2f634_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2f634_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f634_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f634_row0_col0" class="data row0 col0" >0.7222</td>
#       <td id="T_2f634_row0_col1" class="data row0 col1" >0.8889</td>
#       <td id="T_2f634_row0_col2" class="data row0 col2" >0.7222</td>
#       <td id="T_2f634_row0_col3" class="data row0 col3" >0.7349</td>
#       <td id="T_2f634_row0_col4" class="data row0 col4" >0.7253</td>
#       <td id="T_2f634_row0_col5" class="data row0 col5" >0.5833</td>
#       <td id="T_2f634_row0_col6" class="data row0 col6" >0.5861</td>
#     </tr>
#     <tr>
#       <th id="T_2f634_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f634_row1_col0" class="data row1 col0" >0.7778</td>
#       <td id="T_2f634_row1_col1" class="data row1 col1" >0.8681</td>
#       <td id="T_2f634_row1_col2" class="data row1 col2" >0.7778</td>
#       <td id="T_2f634_row1_col3" class="data row1 col3" >0.7738</td>
#       <td id="T_2f634_row1_col4" class="data row1 col4" >0.7641</td>
#       <td id="T_2f634_row1_col5" class="data row1 col5" >0.6667</td>
#       <td id="T_2f634_row1_col6" class="data row1 col6" >0.6761</td>
#     </tr>
#     <tr>
#       <th id="T_2f634_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f634_row2_col0" class="data row2 col0" >0.7778</td>
#       <td id="T_2f634_row2_col1" class="data row2 col1" >0.9097</td>
#       <td id="T_2f634_row2_col2" class="data row2 col2" >0.7778</td>
#       <td id="T_2f634_row2_col3" class="data row2 col3" >0.7937</td>
#       <td id="T_2f634_row2_col4" class="data row2 col4" >0.7817</td>
#       <td id="T_2f634_row2_col5" class="data row2 col5" >0.6667</td>
#       <td id="T_2f634_row2_col6" class="data row2 col6" >0.6698</td>
#     </tr>
#     <tr>
#       <th id="T_2f634_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f634_row3_col0" class="data row3 col0" >0.6111</td>
#       <td id="T_2f634_row3_col1" class="data row3 col1" >0.7894</td>
#       <td id="T_2f634_row3_col2" class="data row3 col2" >0.6111</td>
#       <td id="T_2f634_row3_col3" class="data row3 col3" >0.6317</td>
#       <td id="T_2f634_row3_col4" class="data row3 col4" >0.6185</td>
#       <td id="T_2f634_row3_col5" class="data row3 col5" >0.4167</td>
#       <td id="T_2f634_row3_col6" class="data row3 col6" >0.4186</td>
#     </tr>
#     <tr>
#       <th id="T_2f634_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f634_row4_col0" class="data row4 col0" >0.8333</td>
#       <td id="T
_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_516c7_row9_col0" class="data row9 col0" >0.7647</td>
#       <td id="T_516c7_row9_col1" class="data row9 col1" >0.8743</td>
#       <td id="T_516c7_row9_col2" class="data row9 col2" >0.7647</td>
#       <td id="T_516c7_row9_col3" class="data row9 col3" >0.7689</td>
#       <td id="T_516c7_row9_col4" class="data row9 col4" >0.7510</td>
#       <td id="T_516c7_row9_col5" class="data row9 col5" >0.6495</td>
#       <td id="T_516c7_row9_col6" class="data row9 col6" >0.6632</td>
#     </tr>
#     <tr>
#       <th id="T_516c7_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_516c7_row10_col0" class="data row10 col0" >0.7150</td>
#       <td id="T_516c7_row10_col1" class="data row10 col1" >0.8829</td>
#       <td id="T_516c7_row10_col2" class="data row10 col2" >0.7150</td>
#       <td id="T_516c7_row10_col3" class="data row10 col3" >0.7354</td>
#       <td id="T_516c7_row10_col4" class="data row10 col4" >0.7073</td>
#       <td id="T_516c7_row10_col5" class="data row10 col5" >0.5732</td>
#       <td id="T_516c7_row10_col6" class="data row10 col6" >0.5859</td>
#     </tr>
#     <tr>
#       <th id="T_516c7_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_516c7_row11_col0" class="data row11 col0" >0.1150</td>
#       <td id="T_516c7_row11_col1" class="data row11 col1" >0.0714</td>
#       <td id="T_516c7_row11_col2" class="data row11 col2" >0.1150</td>
#       <td id="T_516c7_row11_col3" class="data row11 col3" >0.1312</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# **SHAP Summary Plot**
#
# Rather than using a typical feature importance bar chart, we use a density scatter plot of SHAP values for each feature to identify how much impact each feature has on the model output for individuals in the validation dataset. Features are sorted by the sum of the SHAP value magnitudes across all samples.

# %%
interpret_model(tuned_rf_pca, plot='summary')

# %%
#explainer = shap.TreeExplainer(tuned_rf_pca)
#X = df.drop('class', axis=1)
#shap_values = explainer.shap_values(X)
#shap.summary_plot(shap_values, X)

# %% [markdown]
# **Visualize a single prediction**

# %%
interpret_model(tuned_rf_pca, plot='reason', observation=32)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iNUQTCO7GMPAIMG5F62A1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.3369318181818184, "outValue": 0.4300000000000005, "link": "identity", "featureNames": ["pca0", "pca1", "pca2"], "features": {"0": {"effect": -0.009264383496980461, "value": 1.8349542617797852}, "1": {"effect": 0.13947525165823285, "value": -1.1342459917068481}, "2": {"effect": -0.0371426863430703, "value": 0.7589365243911743}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iNUQTCO7GMPAIMG5F62A1')
#   );
# </script>

# %% [markdown]
# From the above the plot, we can see the "base value," which is defined as the mean predicted target; and f(x), which is the prediction for a selected observation (i.e. observation number 32). The red-colored features increased the predicted value, while the blue-colored features decreased it. The size of each feature (i.e. Principal Component) indicates the impact it has on the model.

# %% [markdown]
# **Visualize many predictions**

# %%
interpret_model(tuned_rf_pca, plot='reason')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i2XAQF5GYDBFYNATJ9EYC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.3369318181818184, "link": "identity", "featureNames": ["pca0", "pca1", "pca2"], "explanations": [{"outValue": 0.2600000000000009, "simIndex": 70.0, "features": {"0": {"effect": 0.0671116314600223, "value": 0.3573286533355713}, "1": {"effect": -0.11279899724728332, "value": -2.6726412773132324}, "2": {"effect": -0.031244452394556498, "value": 0.10593362152576447}}}, {"outValue": 0.5100000000000007, "simIndex": 62.0, "features": {"0": {"effect": 0.0800167704809879, "value": -0.8513891100883484}, "1": {"effect": 0.09235840336901854, "value": -0.24165381491184235}, "2": {"effect": 0.0006930079681757768, "value": -0.010520443320274353}}}, {"outValue": 0.